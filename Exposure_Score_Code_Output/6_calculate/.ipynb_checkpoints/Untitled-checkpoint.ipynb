# %%
import pandas as pd

# Function to calculate the frequency of each AI verb-noun pair in the uncleaned AI data
def calculate_ai_pair_frequencies(ai_file):
    # Read AI verb-noun pairs from the CSV file (uncleaned data)
    ai_df = pd.read_csv(ai_file)

    # Create a list of AI verb-noun pairs (using 'Verb' and 'Noun' columns)
    ai_verb_noun_pairs = list(zip(ai_df['Verb'], ai_df['Noun']))
    
    # Calculate total number of pairs
    total_ai_pairs = len(ai_verb_noun_pairs)
    
    # Calculate the frequency of each AI verb-noun pair
    frequency_dict = pd.Series(ai_verb_noun_pairs).value_counts(normalize=True).to_dict()  # Normalize to get relative frequency
    
    return frequency_dict, total_ai_pairs

# Function to read the data from a CSV and convert string representations of lists into actual lists of strings
def read_occupation_data(file_name, file_type='csv'):
    if file_type == 'csv':
        df = pd.read_csv(file_name)

    # Convert string representations of lists into actual lists of verb-noun pairs
    if 'Matched Verb-Noun Pairs from AI' in df.columns:
        df['Matched Verb-Noun Pairs from AI'] = df['Matched Verb-Noun Pairs from AI'].apply(
            lambda x: x.split(', ') if isinstance(x, str) else []
        )
    else:
        print("Error: No valid 'Matched Verb-Noun Pairs from AI' column found.")
    return df

# Function to replace 'Not Available' in Task Importance with the average of available task importance values for each occupation
def fill_missing_importance(df):
    # Replace 'Not Available' with NaN
    df['Task Importance'] = df['Task Importance'].replace('Not available', pd.NA)

    # Convert Task Importance to numeric, treating NaN as missing values
    df['Task Importance'] = pd.to_numeric(df['Task Importance'], errors='coerce')

    # Group by Occupation Name and fill NaN with the average task importance for that occupation
    df['Task Importance'] = df.groupby('Occupation Name')['Task Importance'].transform(lambda x: x.fillna(x.mean()))

    return df

# Function to calculate the exposure score using AI pair frequencies
def calculate_exposure_score(task_importances, matched_verb_noun_pairs, frequency_dict):
    weighted_sum_frequencies = 0
    total_weighted_pairs = 0

    # Iterate over each task in the occupation
    for task_idx, task_pairs in enumerate(matched_verb_noun_pairs):
        if not task_pairs:  # Skip if there are no matched pairs
            continue

        # Task importance for the current task
        task_importance = task_importances[task_idx]
        try:
            task_importance = float(task_importance)
        except ValueError:
            continue  # Skip tasks with invalid importance values

        # Process the matched verb-noun pairs
        for pair in set(task_pairs):  # Use set to ensure unique pairs
            # Split the pair into verb and noun
            verb_noun = pair.split(' ')
            if len(verb_noun) != 2:
                print(f"Skipping invalid pair: {pair}")
                continue  # Skip invalid pairs if not exactly two parts

            verb, noun = verb_noun
            frequency = frequency_dict.get((verb, noun), 0)  # Get the frequency from the dict
            weighted_sum_frequencies += task_importance * frequency

        # Add to the total weighted pairs (just counting total verb-noun pairs)
        total_weighted_pairs += task_importance * len(task_pairs)

    # Calculate and return the exposure score using the weighted sum formula
    return weighted_sum_frequencies / total_weighted_pairs if total_weighted_pairs > 0 else 0

# === Main Execution ===
# Step 1: Calculate frequencies of AI verb-noun pairs from the uncleaned data
ai_frequencies, total_extracted_pairs = calculate_ai_pair_frequencies('/Users/twylazhang/Desktop/Directed Research/code_output/3_filter_prepare_compare/filtered_AI_verb_noun_meaningful.csv')

# Step 2: Load the cleaned occupation task data
occupation_df = read_occupation_data('/Users/twylazhang/Desktop/Directed Research/code_output/5_compare/cleaned_matched_pairs.csv', file_type='csv')

# Step 3: Fill missing task importance values with the average importance for the same occupation
occupation_df = fill_missing_importance(occupation_df)
# Out:
# {('use', 'network'): 0.020706543789485887,
#  ('use', 'model'): 0.009780907668231613,
#  ('use', 'learning'): 0.00907088622268591,
#  ('use', 'datum'): 0.008491276879383296,
#  ('learn', 'method'): 0.007650843331594505,
#  ('use', 'intelligence'): 0.006172839506172839,
#  ('face', 'method'): 0.005013620819567612,
#  ('train', 'network'): 0.00392685330087521,
#  ('train', 'model'): 0.0037819509650495564,
#  ('use', 'device'): 0.0035645974613110762,
#  ('provide', 'service'): 0.003550107227728511,
#  ('learn', 'device'): 0.003463165826233119,
#  ('use', 'system'): 0.003376224424737727,
#  ('generate', 'model'): 0.0032747927896597693,
#  ('generate', 'datum'): 0.0028690662493479394,
#  ('use', 'analysis'): 0.0027966150814351127,
#  ('drive', 'method'): 0.0027821248478525473,
#  ('provide', 'information'): 0.0026517127456094592,
#  ('learn', 'system'): 0.0024633397090361095,
#  ('position', 'method'): 0.002434359241870979,
#  ('use', 'technique'): 0.0024198690082884136,
#  ('use', 'method'): 0.002318437373210456,
#  ('use', 'information'): 0.0022604764388801948,
#  ('use', 'sensor'): 0.0022459862052976293,
#  ('generate', 'image'): 0.002188025270967368,
#  ('use', 'image'): 0.002188025270967368,
#  ('control', 'device'): 0.0018692401321509303,
#  ('process', 'datum'): 0.0017967889642381035,
#  ('build', 'system'): 0.001767808497072973,
#  ('detect', 'object'): 0.001738828029907842,
#  ('bear', 'method'): 0.0017243377963252768,
#  ('use', 'signal'): 0.0015794354604996232,
#  ('object', 'method'): 0.0015214745261693619,
#  ('use', 'processing'): 0.0015069842925867964,
#  ('process', 'image'): 0.0014924940590042312,
#  ('train', 'system'): 0.0014635135918391004,
#  ('drive', 'system'): 0.001362081956761143,
#  ('defect', 'method'): 0.0013475917231785775,
#  ('learn', 'model'): 0.0013331014895960123,
#  ('utilize', 'model'): 0.0013331014895960123,
#  ('use', 'machine'): 0.001318611256013447,
#  ('provide', 'content'): 0.001318611256013447,
#  ('detect', 'attack'): 0.0012751405552657508,
#  ('answer', 'method'): 0.0012606503216831856,
#  ('generate', 'information'): 0.0012316698545180547,
#  ('use', 'recognition'): 0.001202689387352924,
#  ('use', 'technology'): 0.0011737089201877935,
#  ('utilize', 'network'): 0.0011737089201877935,
#  ('control', 'vehicle'): 0.0011737089201877935,
#  ('perform', 'operation'): 0.001159218686605228,
#  ('determine', 'method'): 0.0011447284530226628,
#  ('detect', 'event'): 0.0011447284530226628,
#  ('provide', 'recommendation'): 0.0011447284530226628,
#  ('use', 'feature'): 0.0011302382194400974,
#  ('analyze', 'image'): 0.001115747985857532,
#  ('control', 'system'): 0.0010867675186924013,
#  ('receive', 'signal'): 0.0010722772851098359,
#  ('push', 'method'): 0.0010432968179447052,
#  ('extract', 'information'): 0.00102880658436214,
#  ('treat', 'disorder'): 0.0010143163507795746,
#  ('learn', 'technique'): 0.0010143163507795746,
#  ('improve', 'performance'): 0.0010143163507795746,
#  ('use', 'reality'): 0.0009998261171970091,
#  ('pose', 'estimation'): 0.0009998261171970091,
#  ('operate', 'system'): 0.000985335883614444,
#  ('generate', 'network'): 0.0009708456500318785,
#  ('analyze', 'datum'): 0.0009708456500318785,
#  ('use', 'vector'): 0.0009708456500318785,
#  ('construct', 'model'): 0.0009563554164493132,
#  ('compute', 'device'): 0.0009418651828667478,
#  ('learn', 'network'): 0.0009418651828667478,
#  ('use', 'graph'): 0.0009273749492841824,
#  ('implement', 'method'): 0.0009273749492841824,
#  ('provide', 'method'): 0.0009273749492841824,
#  ('monitor', 'method'): 0.0008983944821190518,
#  ('generate', 'representation'): 0.0008983944821190518,
#  ('determine', 'state'): 0.0008983944821190518,
#  ('detect', 'anomaly'): 0.000869414014953921,
#  ('use', 'vision'): 0.0008549237813713557,
#  ('identify', 'object'): 0.0008549237813713557,
#  ('display', 'information'): 0.0008549237813713557,
#  ('generate', 'recommendation'): 0.0008404335477887904,
#  ('provide', 'datum'): 0.0008404335477887904,
#  ('recognize', 'method'): 0.0008404335477887904,
#  ('detect', 'method'): 0.0008404335477887904,
#  ('use', 'feedback'): 0.0008404335477887904,
#  ('monitor', 'system'): 0.0008404335477887904,
#  ('use', 'map'): 0.000825943314206225,
#  ('provide', 'feedback'): 0.0008114530806236596,
#  ('fault', 'method'): 0.0007969628470410943,
#  ('monitor', 'activity'): 0.0007969628470410943,
#  ('predict', 'event'): 0.0007969628470410943,
#  ('search', 'method'): 0.0007969628470410943,
#  ('use', 'tree'): 0.0007969628470410943,
#  ('monitor', 'device'): 0.000782472613458529,
#  ('generate', 'response'): 0.0007679823798759636,
#  ('predict', 'failure'): 0.0007534921462933982,
#  ('receive', 'information'): 0.0007534921462933982,
#  ('determine', 'parameter'): 0.0007390019127108329,
#  ('build', 'model'): 0.0007245116791282676,
#  ('establish', 'model'): 0.0007245116791282676,
#  ('provide', 'interface'): 0.0007100214455457022,
#  ('adjust', 'method'): 0.0007100214455457022,
#  ('treat', 'disease'): 0.0006955312119631368,
#  ('control', 'method'): 0.0006955312119631368,
#  ('use', 'camera'): 0.0006810409783805715,
#  ('use', 'representation'): 0.0006810409783805715,
#  ('use', 'classifier'): 0.0006810409783805715,
#  ('perform', 'analysis'): 0.0006810409783805715,
#  ('predict', 'performance'): 0.0006810409783805715,
#  ('use', 'agent'): 0.0006665507447980062,
#  ('provide', 'system'): 0.0006665507447980062,
#  ('support', 'design'): 0.0006665507447980062,
#  ('use', 'input'): 0.0006665507447980062,
#  ('decode', 'method'): 0.0006520605112154408,
#  ('receive', 'datum'): 0.0006520605112154408,
#  ('distribute', 'method'): 0.0006520605112154408,
#  ('detect', 'behavior'): 0.0006375702776328754,
#  ('distribute', 'system'): 0.0006230800440503101,
#  ('provide', 'assistance'): 0.0006230800440503101,
#  ('optimize', 'network'): 0.0006230800440503101,
#  ('use', 'interface'): 0.0006085898104677448,
#  ('recognize', 'object'): 0.0006085898104677448,
#  ('generate', 'summary'): 0.0006085898104677448,
#  ('determine', 'characteristic'): 0.0006085898104677448,
#  ('identify', 'method'): 0.0006085898104677448,
#  ('generate', 'content'): 0.0006085898104677448,
#  ('generate', 'map'): 0.0006085898104677448,
#  ('transmit', 'datum'): 0.0006085898104677448,
#  ('track', 'method'): 0.0006085898104677448,
#  ('name', 'method'): 0.0006085898104677448,
#  ('detect', 'activity'): 0.0006085898104677448,
#  ('detect', 'defect'): 0.0006085898104677448,
#  ('use', 'computing'): 0.0005940995768851794,
#  ('use', 'algorithm'): 0.0005940995768851794,
#  ('process', 'signal'): 0.0005940995768851794,
#  ('provide', 'control'): 0.0005940995768851794,
#  ('measure', 'method'): 0.0005940995768851794,
#  ('learn', 'prediction'): 0.0005940995768851794,
#  ('diagnose', 'disease'): 0.0005940995768851794,
#  ('base', 'system'): 0.0005940995768851794,
#  ('use', 'pattern'): 0.000579609343302614,
#  ('operate', 'vehicle'): 0.000579609343302614,
#  ('detect', 'change'): 0.000579609343302614,
#  ('set', 'method'): 0.000579609343302614,
#  ('manage', 'datum'): 0.000579609343302614,
#  ('utilize', 'intelligence'): 0.000579609343302614,
#  ('use', 'architecture'): 0.000579609343302614,
#  ('utilize', 'datum'): 0.000579609343302614,
#  ('process', 'information'): 0.0005651191097200487,
#  ('use', 'internet'): 0.0005651191097200487,
#  ('operate', 'device'): 0.0005651191097200487,
#  ('use', 'function'): 0.0005651191097200487,
#  ('adjust', 'parameter'): 0.0005506288761374834,
#  ('use', 'engine'): 0.0005506288761374834,
#  ('drive', 'device'): 0.0005506288761374834,
#  ('generate', 'plan'): 0.0005506288761374834,
#  ('control', 'operation'): 0.0005506288761374834,
#  ('improve', 'quality'): 0.0005506288761374834,
#  ('use', 'prediction'): 0.0005506288761374834,
#  ('perform', 'method'): 0.0005361386425549179,
#  ('utilize', 'learning'): 0.0005361386425549179,
#  ('perform', 'task'): 0.0005361386425549179,
#  ('improve', 'accuracy'): 0.0005361386425549179,
#  ('use', 'profile'): 0.0005361386425549179,
#  ('learn', 'representation'): 0.0005361386425549179,
#  ('pose', 'method'): 0.0005361386425549179,
#  ('facilitate', 'interaction'): 0.0005361386425549179,
#  ('answer', 'system'): 0.0005216484089723526,
#  ('determine', 'information'): 0.0005216484089723526,
#  ('update', 'method'): 0.0005216484089723526,
#  ('use', 'context'): 0.0005216484089723526,
#  ('hear', 'device'): 0.0005216484089723526,
#  ('use', 'detection'): 0.0005216484089723526,
#  ('treat', 'condition'): 0.0005216484089723526,
#  ('update', 'model'): 0.0005216484089723526,
#  ('protect', 'model'): 0.0005071581753897873,
#  ('implement', 'network'): 0.0005071581753897873,
#  ('classify', 'image'): 0.0005071581753897873,
#  ('improve', 'function'): 0.0005071581753897873,
#  ('base', 'method'): 0.0005071581753897873,
#  ('improve', 'efficiency'): 0.0005071581753897873,
#  ('authenticate', 'user'): 0.0005071581753897873,
#  ('use', 'set'): 0.0005071581753897873,
#  ('detect', 'condition'): 0.000492667941807222,
#  ('determine', 'position'): 0.000492667941807222,
#  ('use', 'resource'): 0.000492667941807222,
#  ('determine', 'level'): 0.000492667941807222,
#  ('use', 'array'): 0.000492667941807222,
#  ('predict', 'outcome'): 0.000492667941807222,
#  ('use', 'ledger'): 0.0004781777082246566,
#  ('recommend', 'method'): 0.0004781777082246566,
#  ('generate', 'text'): 0.0004781777082246566,
#  ('use', 'approach'): 0.0004781777082246566,
#  ('use', 'structure'): 0.0004781777082246566,
#  ('control', 'apparatus'): 0.0004636874746420912,
#  ('perform', 'detection'): 0.0004636874746420912,
#  ('predict', 'state'): 0.0004636874746420912,
#  ('transmit', 'information'): 0.0004636874746420912,
#  ('object', 'recognition'): 0.0004636874746420912,
#  ('predict', 'behavior'): 0.0004636874746420912,
#  ('extract', 'datum'): 0.0004636874746420912,
#  ('use', 'platform'): 0.0004636874746420912,
#  ('predict', 'life'): 0.0004636874746420912,
#  ('implement', 'model'): 0.0004636874746420912,
#  ('mitigate', 'attack'): 0.0004491972410595259,
#  ('report', 'information'): 0.0004491972410595259,
#  ('receive', 'channel'): 0.0004491972410595259,
#  ('use', 'tracking'): 0.0004491972410595259,
#  ('protect', 'privacy'): 0.0004491972410595259,
#  ('provide', 'device'): 0.0004491972410595259,
#  ('use', 'source'): 0.0004491972410595259,
#  ('base', 'detection'): 0.0004491972410595259,
#  ('determine', 'value'): 0.0004491972410595259,
#  ('answer', 'question'): 0.0004347070074769605,
#  ('cause', 'analysis'): 0.0004347070074769605,
#  ('implement', 'system'): 0.0004347070074769605,
#  ('provide', 'access'): 0.0004347070074769605,
#  ('use', 'measurement'): 0.0004347070074769605,
#  ('improve', 'health'): 0.0004347070074769605,
#  ('use', 'vehicle'): 0.0004202167738943952,
#  ('combine', 'information'): 0.0004202167738943952,
#  ('provide', 'response'): 0.0004202167738943952,
#  ('update', 'map'): 0.0004202167738943952,
#  ('reconstruct', 'image'): 0.0004202167738943952,
#  ('control', 'access'): 0.0004202167738943952,
#  ('utilize', 'information'): 0.0004202167738943952,
#  ('use', 'processor'): 0.0004202167738943952,
#  ('use', 'text'): 0.0004202167738943952,
#  ('mark', 'method'): 0.0004202167738943952,
#  ('use', 'classification'): 0.0004202167738943952,
#  ('transmit', 'signal'): 0.0004202167738943952,
#  ('learn', 'generation'): 0.0004202167738943952,
#  ('provide', 'suggestion'): 0.0004202167738943952,
#  ('allocate', 'resource'): 0.0004202167738943952,
#  ('store', 'program'): 0.0004202167738943952,
#  ('use', 'environment'): 0.0004057265403118298,
#  ('generate', 'method'): 0.0004057265403118298,
#  ('use', 'database'): 0.0004057265403118298,
#  ('use', 'search'): 0.0004057265403118298,
#  ('create', 'model'): 0.0004057265403118298,
#  ('estimate', 'pose'): 0.0004057265403118298,
#  ('learn', 'classification'): 0.0004057265403118298,
#  ('store', 'datum'): 0.0004057265403118298,
#  ('perform', 'plan'): 0.0004057265403118298,
#  ('display', 'image'): 0.0004057265403118298,
#  ('wear', 'method'): 0.0004057265403118298,
#  ('correct', 'error'): 0.0004057265403118298,
#  ('monitor', 'health'): 0.0004057265403118298,
#  ('charge', 'method'): 0.0003912363067292645,
#  ('monitor', 'user'): 0.0003912363067292645,
#  ('determine', 'device'): 0.0003912363067292645,
#  ('position', 'system'): 0.0003912363067292645,
#  ('manage', 'resource'): 0.0003912363067292645,
#  ('prioritize', 'management'): 0.0003912363067292645,
#  ('extract', 'feature'): 0.0003912363067292645,
#  ('predict', 'risk'): 0.0003912363067292645,
#  ('position', 'device'): 0.0003912363067292645,
#  ('assess', 'risk'): 0.0003912363067292645,
#  ('determine', 'time'): 0.0003912363067292645,
#  ('perform', 'transmission'): 0.0003912363067292645,
#  ('extract', 'method'): 0.0003912363067292645,
#  ('facilitate', 'development'): 0.0003767460731466991,
#  ('object', 'system'): 0.0003767460731466991,
#  ('facilitate', 'transaction'): 0.0003767460731466991,
#  ('determine', 'status'): 0.0003767460731466991,
#  ('use', 'language'): 0.0003767460731466991,
#  ('feature', 'method'): 0.0003767460731466991,
#  ('obtain', 'information'): 0.0003767460731466991,
#  ('identify', 'relationship'): 0.0003767460731466991,
#  ('determine', 'condition'): 0.0003767460731466991,
#  ('have', 'capability'): 0.0003767460731466991,
#  ('encrypt', 'datum'): 0.0003767460731466991,
#  ('train', 'machine'): 0.0003767460731466991,
#  ('have', 'system'): 0.0003767460731466991,
#  ('learn', 'datum'): 0.0003767460731466991,
#  ('capture', 'datum'): 0.0003767460731466991,
#  ('manage', 'system'): 0.0003767460731466991,
#  ('use', 'segmentation'): 0.0003767460731466991,
#  ('recognize', 'speech'): 0.0003767460731466991,
#  ('provide', 'guidance'): 0.0003767460731466991,
#  ('share', 'information'): 0.0003767460731466991,
#  ('estimate', 'state'): 0.0003767460731466991,
#  ('provide', 'therapy'): 0.0003767460731466991,
#  ('use', 'imagery'): 0.0003622558395641338,
#  ('reduce', 'risk'): 0.0003622558395641338,
#  ('read', 'method'): 0.0003622558395641338,
#  ('use', 'parameter'): 0.0003622558395641338,
#  ('provide', 'alert'): 0.0003622558395641338,
#  ('learn', 'apparatus'): 0.0003622558395641338,
#  ('predict', 'quality'): 0.0003622558395641338,
#  ('identify', 'condition'): 0.0003622558395641338,
#  ('learn', 'platform'): 0.0003622558395641338,
#  ('solve', 'problem'): 0.0003622558395641338,
#  ('obtain', 'method'): 0.0003622558395641338,
#  ('collect', 'datum'): 0.0003622558395641338,
#  ('flow', 'method'): 0.0003622558395641338,
#  ('use', 'object'): 0.0003622558395641338,
#  ('provide', 'security'): 0.0003622558395641338,
#  ('use', 'module'): 0.0003622558395641338,
#  ('output', 'information'): 0.0003622558395641338,
#  ('generate', 'interface'): 0.0003622558395641338,
#  ('enable', 'system'): 0.0003622558395641338,
#  ('use', 'knowledge'): 0.0003622558395641338,
#  ('aid', 'system'): 0.0003622558395641338,
#  ('establish', 'method'): 0.0003477656059815684,
#  ('share', 'datum'): 0.0003477656059815684,
#  ('protect', 'system'): 0.0003477656059815684,
#  ('provide', 'management'): 0.0003477656059815684,
#  ('message', 'system'): 0.0003477656059815684,
#  ('detect', 'obstacle'): 0.0003477656059815684,
#  ('use', 'rate'): 0.0003477656059815684,
#  ('use', 'robot'): 0.0003477656059815684,
#  ('obtain', 'datum'): 0.0003477656059815684,
#  ('predict', 'method'): 0.0003477656059815684,
#  ('hear', 'aid'): 0.0003477656059815684,
#  ('use', 'communication'): 0.0003477656059815684,
#  ('learn', 'policy'): 0.0003477656059815684,
#  ('predict', 'status'): 0.0003477656059815684,
#  ('generate', 'question'): 0.0003477656059815684,
#  ('identify', 'behavior'): 0.0003477656059815684,
#  ('determine', 'risk'): 0.0003477656059815684,
#  ('manage', 'information'): 0.0003332753723990031,
#  ('identify', 'pattern'): 0.0003332753723990031,
#  ('determine', 'location'): 0.0003332753723990031,
#  ('model', 'behavior'): 0.0003332753723990031,
#  ('determine', 'model'): 0.0003332753723990031,
#  ('provide', 'function'): 0.0003332753723990031,
#  ('detect', 'error'): 0.0003332753723990031,
#  ('recognize', 'image'): 0.0003332753723990031,
#  ('recover', 'datum'): 0.0003332753723990031,
#  ('target', 'method'): 0.0003332753723990031,
#  ('navigate', 'vehicle'): 0.0003332753723990031,
#  ('use', 'computer'): 0.0003332753723990031,
#  ('identify', 'information'): 0.0003332753723990031,
#  ('select', 'image'): 0.0003332753723990031,
#  ('determine', 'similarity'): 0.0003332753723990031,
#  ('generate', 'profile'): 0.0003187851388164377,
#  ('evaluate', 'quality'): 0.0003187851388164377,
#  ('classify', 'datum'): 0.0003187851388164377,
#  ('detect', 'movement'): 0.0003187851388164377,
#  ('control', 'robot'): 0.0003187851388164377,
#  ('predict', 'value'): 0.0003187851388164377,
#  ('log', 'method'): 0.0003187851388164377,
#  ('treat', 'patient'): 0.0003187851388164377,
#  ('optimize', 'performance'): 0.0003187851388164377,
#  ('detect', 'abnormality'): 0.0003187851388164377,
#  ('detect', 'disease'): 0.0003187851388164377,
#  ('combine', 'datum'): 0.0003187851388164377,
#  ('treat', 'cancer'): 0.0003187851388164377,
#  ('click', 'method'): 0.0003187851388164377,
#  ('perform', 'estimation'): 0.0003187851388164377,
#  ('use', 'modeling'): 0.0003187851388164377,
#  ('perform', 'communication'): 0.0003187851388164377,
#  ('operate', 'network'): 0.0003187851388164377,
#  ('diagnose', 'fault'): 0.0003187851388164377,
#  ('have', 'function'): 0.0003187851388164377,
#  ('construct', 'graph'): 0.0003187851388164377,
#  ('capture', 'image'): 0.0003187851388164377,
#  ('defect', 'system'): 0.0003187851388164377,
#  ('assist', 'device'): 0.0003187851388164377,
#  ('have', 'device'): 0.0003187851388164377,
#  ('monitor', 'status'): 0.0003187851388164377,
#  ('edge', 'method'): 0.0003187851388164377,
#  ('generate', 'video'): 0.0003187851388164377,
#  ('route', 'method'): 0.0003187851388164377,
#  ('perform', 'procedure'): 0.0003187851388164377,
#  ('receive', 'method'): 0.0003187851388164377,
#  ('generate', 'set'): 0.0003187851388164377,
#  ('use', 'convolution'): 0.0003042949052338724,
#  ('monitor', 'state'): 0.0003042949052338724,
#  ('face', 'recognition'): 0.0003042949052338724,
#  ('build', 'method'): 0.0003042949052338724,
#  ('detect', 'threat'): 0.0003042949052338724,
#  ('remove', 'method'): 0.0003042949052338724,
#  ('access', 'datum'): 0.0003042949052338724,
#  ('detect', 'target'): 0.0003042949052338724,
#  ('control', 'signal'): 0.0003042949052338724,
#  ('use', 'identification'): 0.0003042949052338724,
#  ('use', 'server'): 0.0003042949052338724,
#  ('assess', 'state'): 0.0003042949052338724,
#  ('use', 'protocol'): 0.0003042949052338724,
#  ('learn', 'identification'): 0.0003042949052338724,
#  ('perform', 'action'): 0.0003042949052338724,
#  ('face', 'detection'): 0.0003042949052338724,
#  ('optimize', 'operation'): 0.0003042949052338724,
#  ('object', 'identification'): 0.0003042949052338724,
#  ('cluster', 'method'): 0.0003042949052338724,
#  ('scan', 'system'): 0.0003042949052338724,
#  ('configure', 'system'): 0.0003042949052338724,
#  ('learn', 'analysis'): 0.000289804671651307,
#  ('provide', 'image'): 0.000289804671651307,
#  ('enhance', 'performance'): 0.000289804671651307,
#  ('change', 'method'): 0.000289804671651307,
#  ('use', 'unit'): 0.000289804671651307,
#  ('use', 'imaging'): 0.000289804671651307,
#  ('determine', 'content'): 0.000289804671651307,
#  ('use', 'score'): 0.000289804671651307,
#  ('learn', 'operation'): 0.000289804671651307,
#  ('learn', 'program'): 0.000289804671651307,
#  ('train', 'classifier'): 0.000289804671651307,
#  ('provide', 'notification'): 0.000289804671651307,
#  ('apply', 'model'): 0.000289804671651307,
#  ('select', 'model'): 0.000289804671651307,
#  ('use', 'combination'): 0.000289804671651307,
#  ('compile', 'method'): 0.000289804671651307,
#  ('detect', 'region'): 0.000289804671651307,
#  ('facilitate', 'communication'): 0.000289804671651307,
#  ('perform', 'recognition'): 0.000289804671651307,
#  ('identify', 'datum'): 0.000289804671651307,
#  ('enhance', 'function'): 0.000289804671651307,
#  ('use', 'policy'): 0.000289804671651307,
#  ('manage', 'device'): 0.0002753144380687417,
#  ('display', 'datum'): 0.0002753144380687417,
#  ('use', 'gesture'): 0.0002753144380687417,
#  ('face', 'system'): 0.0002753144380687417,
#  ('use', 'sequence'): 0.0002753144380687417,
#  ('encode', 'method'): 0.0002753144380687417,
#  ('spike', 'network'): 0.0002753144380687417,
#  ('use', 'fusion'): 0.0002753144380687417,
#  ('use', 'stimulation'): 0.0002753144380687417,
#  ('perform', 'search'): 0.0002753144380687417,
#  ('predict', 'response'): 0.0002753144380687417,
#  ('utilize', 'processing'): 0.0002753144380687417,
#  ('use', 'plurality'): 0.0002753144380687417,
#  ('have', 'engine'): 0.0002753144380687417,
#  ('apply', 'network'): 0.0002753144380687417,
#  ('embed', 'method'): 0.0002753144380687417,
#  ('use', 'characteristic'): 0.0002753144380687417,
#  ('create', 'product'): 0.0002753144380687417,
#  ('evaluate', 'performance'): 0.0002753144380687417,
#  ('hear', 'system'): 0.0002753144380687417,
#  ('recognize', 'character'): 0.0002753144380687417,
#  ('synthesize', 'datum'): 0.0002753144380687417,
#  ('provide', 'experience'): 0.0002753144380687417,
#  ('facilitate', 'analysis'): 0.0002753144380687417,
#  ('configure', 'device'): 0.0002753144380687417,
#  ('classify', 'behavior'): 0.0002753144380687417,
#  ('use', 'process'): 0.0002753144380687417,
#  ('switch', 'method'): 0.0002753144380687417,
#  ('use', 'token'): 0.0002753144380687417,
#  ('integrate', 'information'): 0.0002753144380687417,
#  ('classify', 'method'): 0.0002753144380687417,
#  ('select', 'object'): 0.0002753144380687417,
#  ('analyze', 'behavior'): 0.0002753144380687417,
#  ('pose', 'determination'): 0.0002753144380687417,
#  ('learn', 'optimization'): 0.0002753144380687417,
#  ('integrate', 'feature'): 0.0002753144380687417,
#  ('evaluate', 'risk'): 0.0002608242044861763,
#  ('assist', 'method'): 0.0002608242044861763,
#  ('use', 'scan'): 0.0002608242044861763,
#  ('track', 'object'): 0.0002608242044861763,
#  ('base', 'modeling'): 0.0002608242044861763,
#  ('perform', 'measurement'): 0.0002608242044861763,
#  ('use', 'matrix'): 0.0002608242044861763,
#  ('manage', 'model'): 0.0002608242044861763,
#  ('provide', 'detection'): 0.0002608242044861763,
#  ('recommend', 'content'): 0.0002608242044861763,
#  ('classify', 'object'): 0.0002608242044861763,
#  ('predict', 'likelihood'): 0.0002608242044861763,
#  ('construct', 'map'): 0.0002608242044861763,
#  ('grab', 'method'): 0.0002608242044861763,
#  ('use', 'rule'): 0.0002608242044861763,
#  ('use', 'radar'): 0.0002608242044861763,
#  ('trigger', 'action'): 0.0002608242044861763,
#  ('code', 'method'): 0.0002608242044861763,
#  ('determine', 'type'): 0.0002608242044861763,
#  ('recognize', 'expression'): 0.0002608242044861763,
#  ('provide', 'stimulation'): 0.0002608242044861763,
#  ('improve', 'experience'): 0.0002608242044861763,
#  ('assist', 'system'): 0.0002608242044861763,
#  ('update', 'parameter'): 0.0002608242044861763,
#  ('facilitate', 'management'): 0.0002608242044861763,
#  ('use', 'control'): 0.0002608242044861763,
#  ('provide', 'result'): 0.0002608242044861763,
#  ('identify', 'anomaly'): 0.0002608242044861763,
#  ('learn', 'framework'): 0.0002608242044861763,
#  ('use', 'sensing'): 0.0002608242044861763,
#  ('object', 'device'): 0.0002608242044861763,
#  ('determine', 'score'): 0.000246333970903611,
#  ('monitor', 'performance'): 0.000246333970903611,
#  ('fuse', 'datum'): 0.000246333970903611,
#  ('learn', 'algorithm'): 0.000246333970903611,
#  ('deploy', 'model'): 0.000246333970903611,
#  ('detect', 'state'): 0.000246333970903611,
#  ('perform', 'learning'): 0.000246333970903611,
#  ('use', 'training'): 0.000246333970903611,
#  ('use', 'hardware'): 0.000246333970903611,
#  ('shoot', 'method'): 0.000246333970903611,
#  ('enhance', 'network'): 0.000246333970903611,
#  ('present', 'content'): 0.000246333970903611,
#  ('scan', 'method'): 0.000246333970903611,
#  ('use', 'memory'): 0.000246333970903611,
#  ('use', 'assistant'): 0.000246333970903611,
#  ('learn', 'pattern'): 0.000246333970903611,
#  ('generate', 'vector'): 0.000246333970903611,
#  ('integrate', 'datum'): 0.000246333970903611,
#  ('object', 'model'): 0.000246333970903611,
#  ('use', 'decomposition'): 0.000246333970903611,
#  ('test', 'system'): 0.000246333970903611,
#  ('understand', 'method'): 0.000246333970903611,
#  ('image', 'device'): 0.000246333970903611,
#  ('optimize', 'utilization'): 0.000246333970903611,
#  ('improve', 'training'): 0.000246333970903611,
#  ('cross', 'system'): 0.000246333970903611,
#  ('predict', 'interaction'): 0.000246333970903611,
#  ('charge', 'system'): 0.000246333970903611,
#  ('process', 'query'): 0.0002318437373210456,
#  ('accelerate', 'network'): 0.0002318437373210456,
#  ('learn', 'detection'): 0.0002318437373210456,
#  ('use', 'template'): 0.0002318437373210456,
#  ('crowd', 'method'): 0.0002318437373210456,
#  ('drive', 'control'): 0.0002318437373210456,
#  ('determine', 'degree'): 0.0002318437373210456,
#  ('combine', 'learning'): 0.0002318437373210456,
#  ('have', 'database'): 0.0002318437373210456,
#  ('provide', 'insight'): 0.0002318437373210456,
#  ('control', 'element'): 0.0002318437373210456,
#  ('detect', 'datum'): 0.0002318437373210456,
#  ('test', 'device'): 0.0002318437373210456,
#  ('identify', 'characteristic'): 0.0002318437373210456,
#  ('identify', 'entity'): 0.0002318437373210456,
#  ('create', 'plan'): 0.0002318437373210456,
#  ('play', 'method'): 0.0002318437373210456,
#  ('use', 'cell'): 0.0002318437373210456,
#  ('use', 'distillation'): 0.0002318437373210456,
#  ('monitor', 'event'): 0.0002318437373210456,
#  ('control', 'power'): 0.0002318437373210456,
#  ('optimize', 'parameter'): 0.0002318437373210456,
#  ('search', 'image'): 0.0002318437373210456,
#  ('use', 'framework'): 0.0002318437373210456,
#  ('capture', 'information'): 0.0002318437373210456,
#  ('control', 'process'): 0.0002318437373210456,
#  ('monitor', 'progress'): 0.0002318437373210456,
#  ('characterize', 'condition'): 0.0002318437373210456,
#  ('determine', 'intention'): 0.0002318437373210456,
#  ('integrate', 'content'): 0.0002318437373210456,
#  ('identify', 'vehicle'): 0.0002318437373210456,
#  ('process', 'input'): 0.0002318437373210456,
#  ('learn', 'mechanism'): 0.0002318437373210456,
#  ('create', 'datum'): 0.0002318437373210456,
#  ('use', 'mapping'): 0.0002318437373210456,
#  ('use', 'factor'): 0.0002318437373210456,
#  ('manage', 'network'): 0.0002318437373210456,
#  ('use', 'measure'): 0.0002318437373210456,
#  ('recommend', 'item'): 0.0002318437373210456,
#  ('measure', 'device'): 0.0002318437373210456,
#  ('generate', 'output'): 0.0002318437373210456,
#  ('push', 'information'): 0.00021735350373848025,
#  ('reduce', 'latency'): 0.00021735350373848025,
#  ('communicate', 'information'): 0.00021735350373848025,
#  ('detect', 'fault'): 0.00021735350373848025,
#  ('learn', 'classifier'): 0.00021735350373848025,
#  ('unload', 'method'): 0.00021735350373848025,
#  ('update', 'datum'): 0.00021735350373848025,
#  ('use', 'loss'): 0.00021735350373848025,
#  ('track', 'device'): 0.00021735350373848025,
#  ('determine', 'preference'): 0.00021735350373848025,
#  ('transfer', 'datum'): 0.00021735350373848025,
#  ('comprise', 'system'): 0.00021735350373848025,
#  ('render', 'content'): 0.00021735350373848025,
#  ('enable', 'device'): 0.00021735350373848025,
#  ('count', 'method'): 0.00021735350373848025,
#  ('improve', 'outcome'): 0.00021735350373848025,
#  ('involve', 'device'): 0.00021735350373848025,
#  ('measure', 'parameter'): 0.00021735350373848025,
#  ('learn', 'training'): 0.00021735350373848025,
#  ('identify', 'gesture'): 0.00021735350373848025,
#  ('optimize', 'system'): 0.00021735350373848025,
#  ('estimate', 'time'): 0.00021735350373848025,
#  ('utilize', 'cloud'): 0.00021735350373848025,
#  ('drive', 'apparatus'): 0.00021735350373848025,
#  ('verify', 'identity'): 0.00021735350373848025,
#  ('utilize', 'device'): 0.00021735350373848025,
#  ('generate', 'feature'): 0.00021735350373848025,
#  ('display', 'content'): 0.00021735350373848025,
#  ('provide', 'answer'): 0.00021735350373848025,
#  ('understand', 'system'): 0.00021735350373848025,
#  ('move', 'method'): 0.00021735350373848025,
#  ('combine', 'mechanism'): 0.00021735350373848025,
#  ('manufacture', 'device'): 0.00021735350373848025,
#  ('manage', 'communication'): 0.00021735350373848025,
#  ('improve', 'understanding'): 0.00021735350373848025,
#  ('track', 'movement'): 0.00021735350373848025,
#  ('adapt', 'system'): 0.00021735350373848025,
#  ('provide', 'guide'): 0.00021735350373848025,
#  ('use', 'content'): 0.00021735350373848025,
#  ('process', 'utterance'): 0.00021735350373848025,
#  ('determine', 'datum'): 0.00021735350373848025,
#  ('evaluate', 'image'): 0.00021735350373848025,
#  ('detect', 'location'): 0.00021735350373848025,
#  ('use', 'primitive'): 0.00021735350373848025,
#  ('use', 'augmentation'): 0.00021735350373848025,
#  ('detect', 'apparatus'): 0.00021735350373848025,
#  ('control', 'exposure'): 0.00021735350373848025,
#  ('improve', 'sleep'): 0.00021735350373848025,
#  ('process', 'language'): 0.00021735350373848025,
#  ('sense', 'method'): 0.0002028632701559149,
#  ('analyze', 'sample'): 0.0002028632701559149,
#  ('detect', 'system'): 0.0002028632701559149,
#  ('convert', 'datum'): 0.0002028632701559149,
#  ('improve', 'detection'): 0.0002028632701559149,
#  ('perform', 'computation'): 0.0002028632701559149,
#  ('identify', 'content'): 0.0002028632701559149,
#  ('predict', 'condition'): 0.0002028632701559149,
#  ('use', 'signature'): 0.0002028632701559149,
#  ('treat', 'impairment'): 0.0002028632701559149,
#  ('carry', 'method'): 0.0002028632701559149,
#  ('detect', 'image'): 0.0002028632701559149,
#  ('process', 'task'): 0.0002028632701559149,
#  ('identify', 'type'): 0.0002028632701559149,
#  ('base', 'analysis'): 0.0002028632701559149,
#  ('determine', 'clock'): 0.0002028632701559149,
#  ('comprise', 'device'): 0.0002028632701559149,
#  ('generate', 'sample'): 0.0002028632701559149,
#  ('provide', 'intelligence'): 0.0002028632701559149,
#  ('automate', 'identification'): 0.0002028632701559149,
#  ('monitor', 'environment'): 0.0002028632701559149,
#  ('predict', 'property'): 0.0002028632701559149,
#  ('manage', 'power'): 0.0002028632701559149,
#  ('identify', 'abnormality'): 0.0002028632701559149,
#  ('use', 'metric'): 0.0002028632701559149,
#  ('sequence', 'method'): 0.0002028632701559149,
#  ('crack', 'method'): 0.0002028632701559149,
#  ('use', 'filter'): 0.0002028632701559149,
#  ('optimize', 'plan'): 0.0002028632701559149,
#  ('determine', 'quality'): 0.0002028632701559149,
#  ('identify', 'feature'): 0.0002028632701559149,
#  ('identify', 'device'): 0.0002028632701559149,
#  ('use', 'component'): 0.0002028632701559149,
#  ('detect', 'user'): 0.0002028632701559149,
#  ('use', 'cue'): 0.0002028632701559149,
#  ('message', 'application'): 0.0002028632701559149,
#  ('generate', 'path'): 0.0002028632701559149,
#  ('measure', 'motion'): 0.0002028632701559149,
#  ('assign', 'label'): 0.0002028632701559149,
#  ('use', 'transfer'): 0.0002028632701559149,
#  ('optimize', 'process'): 0.0002028632701559149,
#  ('drive', 'vehicle'): 0.0002028632701559149,
#  ('enhance', 'resolution'): 0.0002028632701559149,
#  ('sense', 'image'): 0.0002028632701559149,
#  ('analyze', 'method'): 0.0002028632701559149,
#  ('generate', 'annotation'): 0.0002028632701559149,
#  ('improve', 'safety'): 0.0002028632701559149,
#  ('have', 'plurality'): 0.0002028632701559149,
#  ('construct', 'system'): 0.0002028632701559149,
#  ('decode', 'image'): 0.0002028632701559149,
#  ('call', 'method'): 0.0002028632701559149,
#  ('mount', 'system'): 0.0002028632701559149,
#  ('use', 'generation'): 0.0002028632701559149,
#  ('provide', 'communication'): 0.0002028632701559149,
#  ('select', 'network'): 0.0002028632701559149,
#  ('monitor', 'safety'): 0.0002028632701559149,
#  ('deliver', 'point'): 0.0002028632701559149,
#  ('implement', 'classification'): 0.0002028632701559149,
#  ('enhance', 'recovery'): 0.0002028632701559149,
#  ('assess', 'quality'): 0.0002028632701559149,
#  ('weld', 'method'): 0.0002028632701559149,
#  ('enable', 'network'): 0.0002028632701559149,
#  ('detect', 'space'): 0.0002028632701559149,
#  ('provide', 'set'): 0.0002028632701559149,
#  ('present', 'information'): 0.0002028632701559149,
#  ('support', 'argumentation'): 0.0002028632701559149,
#  ('monitor', 'condition'): 0.0002028632701559149,
#  ('tamper', 'method'): 0.0002028632701559149,
#  ('provide', 'representation'): 0.0002028632701559149,
#  ('deliver', 'content'): 0.00018837303657334955,
#  ('determine', 'metric'): 0.00018837303657334955,
#  ('facilitate', 'awareness'): 0.00018837303657334955,
#  ('fault', 'system'): 0.00018837303657334955,
#  ('provide', 'interaction'): 0.00018837303657334955,
#  ('process', 'claim'): 0.00018837303657334955,
#  ('use', 'flow'): 0.00018837303657334955,
#  ('predict', 'location'): 0.00018837303657334955,
#  ('predict', 'datum'): 0.00018837303657334955,
#  ('distribute', 'platform'): 0.00018837303657334955,
#  ('use', 'marker'): 0.00018837303657334955,
#  ('personalize', 'experience'): 0.00018837303657334955,
#  ('gesture', 'method'): 0.00018837303657334955,
#  ('implement', 'interface'): 0.00018837303657334955,
#  ('identify', 'change'): 0.00018837303657334955,
#  ('merge', 'network'): 0.00018837303657334955,
#  ('determine', 'registration'): 0.00018837303657334955,
#  ('model', 'method'): 0.00018837303657334955,
#  ('acquire', 'datum'): 0.00018837303657334955,
#  ('present', 'datum'): 0.00018837303657334955,
#  ('detect', 'face'): 0.00018837303657334955,
#  ('detect', 'infection'): 0.00018837303657334955,
#  ('learn', 'task'): 0.00018837303657334955,
#  ('check', 'method'): 0.00018837303657334955,
#  ('perform', 'processing'): 0.00018837303657334955,
#  ('analyze', 'activity'): 0.00018837303657334955,
#  ('detect', 'device'): 0.00018837303657334955,
#  ('use', 'value'): 0.00018837303657334955,
#  ('employ', 'intelligence'): 0.00018837303657334955,
#  ('treat', 'dysfunction'): 0.00018837303657334955,
#  ('classify', 'information'): 0.00018837303657334955,
#  ('use', 'table'): 0.00018837303657334955,
#  ('object', 'apparatus'): 0.00018837303657334955,
#  ('draw', 'method'): 0.00018837303657334955,
#  ('make', 'decision'): 0.00018837303657334955,
#  ('synthesize', 'image'): 0.00018837303657334955,
#  ('analyze', 'response'): 0.00018837303657334955,
#  ('control', 'quality'): 0.00018837303657334955,
#  ('determine', 'image'): 0.00018837303657334955,
#  ('predict', 'occurrence'): 0.00018837303657334955,
#  ('dispatch', 'method'): 0.00018837303657334955,
#  ('predict', 'parameter'): 0.00018837303657334955,
#  ('learn', 'selection'): 0.00018837303657334955,
#  ('use', 'descriptor'): 0.00018837303657334955,
#  ('detect', 'request'): 0.00018837303657334955,
#  ('predict', 'intent'): 0.00018837303657334955,
#  ('use', 'surface'): 0.00018837303657334955,
#  ('use', 'mining'): 0.00018837303657334955,
#  ('use', 'application'): 0.00018837303657334955,
#  ('process', 'request'): 0.00018837303657334955,
#  ('use', 'motion'): 0.00018837303657334955,
#  ('customize', 'response'): 0.00018837303657334955,
#  ('use', 'level'): 0.00018837303657334955,
#  ('perform', 'authentication'): 0.00018837303657334955,
#  ('optimize', 'outcome'): 0.00018837303657334955,
#  ('use', 'dialog'): 0.00018837303657334955,
#  ('detect', 'fraud'): 0.00018837303657334955,
#  ('move', 'object'): 0.00018837303657334955,
#  ('learn', 'processing'): 0.00018837303657334955,
#  ('provide', 'platform'): 0.00018837303657334955,
#  ('determine', 'activity'): 0.00018837303657334955,
#  ('use', 'point'): 0.00018837303657334955,
#  ('identify', 'action'): 0.00018837303657334955,
#  ('use', 'document'): 0.00018837303657334955,
#  ('use', 'tomography'): 0.00018837303657334955,
#  ('assess', 'function'): 0.00018837303657334955,
#  ('use', 'index'): 0.00018837303657334955,
#  ('determine', 'setting'): 0.00018837303657334955,
#  ('detect', 'indication'): 0.00018837303657334955,
#  ('learn', 'workflow'): 0.00018837303657334955,
#  ('diagnose', 'lesion'): 0.00018837303657334955,
#  ('identify', 'target'): 0.00018837303657334955,
#  ('perform', 'instruction'): 0.0001738828029907842,
#  ('calculate', 'method'): 0.0001738828029907842,
#  ('personalize', 'method'): 0.0001738828029907842,
#  ('deliver', 'stimulation'): 0.0001738828029907842,
#  ('perform', 'process'): 0.0001738828029907842,
#  ('use', 'programming'): 0.0001738828029907842,
#  ('divide', 'method'): 0.0001738828029907842,
#  ('assign', 'patient'): 0.0001738828029907842,
#  ('provide', 'medium'): 0.0001738828029907842,
#  ('update', 'system'): 0.0001738828029907842,
#  ('estimate', 'parameter'): 0.0001738828029907842,
#  ('predict', 'pattern'): 0.0001738828029907842,
#  ('train', 'method'): 0.0001738828029907842,
#  ('segment', 'image'): 0.0001738828029907842,
#  ('generate', 'route'): 0.0001738828029907842,
#  ('identify', 'image'): 0.0001738828029907842,
#  ('display', 'interface'): 0.0001738828029907842,
#  ('perform', 'function'): 0.0001738828029907842,
#  ('predict', 'consumption'): 0.0001738828029907842,
#  ('photograph', 'method'): 0.0001738828029907842,
#  ('use', 'channel'): 0.0001738828029907842,
#  ('use', 'attribute'): 0.0001738828029907842,
#  ('provide', 'support'): 0.0001738828029907842,
#  ('use', 'base'): 0.0001738828029907842,
#  ('execute', 'operation'): 0.0001738828029907842,
#  ('determine', 'recommendation'): 0.0001738828029907842,
#  ('optimize', 'model'): 0.0001738828029907842,
#  ('generate', 'script'): 0.0001738828029907842,
#  ('have', 'feature'): 0.0001738828029907842,
#  ('use', 'element'): 0.0001738828029907842,
#  ('call', 'system'): 0.0001738828029907842,
#  ('execute', 'task'): 0.0001738828029907842,
#  ('use', 'estimation'): 0.0001738828029907842,
#  ('use', 'log'): 0.0001738828029907842,
#  ('execute', 'method'): 0.0001738828029907842,
#  ('enhance', 'response'): 0.0001738828029907842,
#  ('display', 'method'): 0.0001738828029907842,
#  ('use', 'integration'): 0.0001738828029907842,
#  ('support', 'internet'): 0.0001738828029907842,
#  ('construct', 'network'): 0.0001738828029907842,
#  ('execute', 'application'): 0.0001738828029907842,
#  ('process', 'method'): 0.0001738828029907842,
#  ('use', 'operation'): 0.0001738828029907842,
#  ('identify', 'patient'): 0.0001738828029907842,
#  ('reduce', 'consumption'): 0.0001738828029907842,
#  ('improve', 'process'): 0.0001738828029907842,
#  ('use', 'understanding'): 0.0001738828029907842,
#  ('deliver', 'service'): 0.0001738828029907842,
#  ('use', 'controller'): 0.0001738828029907842,
#  ('acquire', 'image'): 0.0001738828029907842,
#  ('accelerate', 'operation'): 0.0001738828029907842,
#  ('distribute', 'content'): 0.0001738828029907842,
#  ('generate', 'audio'): 0.0001738828029907842,
#  ('characterize', 'tissue'): 0.0001738828029907842,
#  ('update', 'network'): 0.0001738828029907842,
#  ('use', 'reconnaissance'): 0.0001738828029907842,
#  ('distribute', 'computation'): 0.0001738828029907842,
#  ('predict', 'health'): 0.0001738828029907842,
#  ('predict', 'trajectory'): 0.0001738828029907842,
#  ('generate', 'assessment'): 0.0001738828029907842,
#  ('write', 'datum'): 0.0001738828029907842,
#  ('use', 'twin'): 0.0001738828029907842,
#  ('generate', 'sequence'): 0.0001738828029907842,
#  ('predict', 'metric'): 0.0001738828029907842,
#  ('simulate', 'datum'): 0.0001738828029907842,
#  ('teach', 'method'): 0.0001738828029907842,
#  ('detect', 'situation'): 0.0001738828029907842,
#  ('use', 'query'): 0.0001738828029907842,
#  ('update', 'record'): 0.0001738828029907842,
#  ('incorporate', 'learning'): 0.0001738828029907842,
#  ('use', 'inference'): 0.0001738828029907842,
#  ('implement', 'learning'): 0.0001738828029907842,
#  ('improve', 'recognition'): 0.0001738828029907842,
#  ('provide', 'prediction'): 0.0001738828029907842,
#  ('say', 'method'): 0.0001738828029907842,
#  ('predict', 'probability'): 0.0001738828029907842,
#  ('identify', 'event'): 0.0001738828029907842,
#  ('facilitate', 'prediction'): 0.0001738828029907842,
#  ('provide', 'product'): 0.0001738828029907842,
#  ('recognize', 'voice'): 0.0001738828029907842,
#  ('use', 'container'): 0.0001738828029907842,
#  ('provide', 'mode'): 0.0001738828029907842,
#  ('detect', 'emotion'): 0.0001738828029907842,
#  ('trace', 'method'): 0.0001738828029907842,
#  ('generate', 'system'): 0.0001738828029907842,
#  ('learn', 'service'): 0.0001738828029907842,
#  ('use', 'selection'): 0.0001738828029907842,
#  ('assist', 'platform'): 0.0001738828029907842,
#  ('receive', 'device'): 0.0001738828029907842,
#  ('detect', 'point'): 0.0001738828029907842,
#  ('determine', 'policy'): 0.0001738828029907842,
#  ('use', 'cluster'): 0.0001738828029907842,
#  ('identify', 'individual'): 0.0001738828029907842,
#  ('determine', 'property'): 0.0001738828029907842,
#  ('identify', 'system'): 0.0001738828029907842,
#  ('analyze', 'information'): 0.0001738828029907842,
#  ('use', 'question'): 0.0001738828029907842,
#  ('leverage', 'datum'): 0.0001738828029907842,
#  ('optimize', 'allocation'): 0.00015939256940821885,
#  ('characterize', 'feature'): 0.00015939256940821885,
#  ('edit', 'image'): 0.00015939256940821885,
#  ('use', 'observation'): 0.00015939256940821885,
#  ('analyze', 'document'): 0.00015939256940821885,
#  ('improve', 'interaction'): 0.00015939256940821885,
#  ('use', 'word'): 0.00015939256940821885,
#  ('base', 'monitoring'): 0.00015939256940821885,
#  ('support', 'transmission'): 0.00015939256940821885,
#  ('extract', 'fact'): 0.00015939256940821885,
#  ('adjust', 'resistance'): 0.00015939256940821885,
#  ('enable', 'compliance'): 0.00015939256940821885,
#  ('control', 'display'): 0.00015939256940821885,
#  ('record', 'medium'): 0.00015939256940821885,
#  ('use', 'speech'): 0.00015939256940821885,
#  ('determine', 'path'): 0.00015939256940821885,
#  ('identify', 'activity'): 0.00015939256940821885,
#  ('predict', 'site'): 0.00015939256940821885,
#  ('use', 'service'): 0.00015939256940821885,
#  ('manage', 'process'): 0.00015939256940821885,
#  ('determine', 'action'): 0.00015939256940821885,
#  ('detect', 'information'): 0.00015939256940821885,
#  ('convert', 'text'): 0.00015939256940821885,
#  ('use', 'library'): 0.00015939256940821885,
#  ('model', 'relationship'): 0.00015939256940821885,
#  ('source', 'candidate'): 0.00015939256940821885,
#  ('defect', 'device'): 0.00015939256940821885,
#  ('predict', 'incident'): 0.00015939256940821885,
#  ('label', 'datum'): 0.00015939256940821885,
#  ('increase', 'efficiency'): 0.00015939256940821885,
#  ('mount', 'display'): 0.00015939256940821885,
#  ('use', 'detector'): 0.00015939256940821885,
#  ('execute', 'function'): 0.00015939256940821885,
#  ('generate', 'signal'): 0.00015939256940821885,
#  ('control', 'appliance'): 0.00015939256940821885,
#  ('detect', 'identity'): 0.00015939256940821885,
#  ('generate', 'device'): 0.00015939256940821885,
#  ('provide', 'privacy'): 0.00015939256940821885,
#  ('pose', 'detection'): 0.00015939256940821885,
#  ('determine', 'rate'): 0.00015939256940821885,
#  ('associate', 'music'): 0.00015939256940821885,
#  ('provide', 'warning'): 0.00015939256940821885,
#  ('protect', 'network'): 0.00015939256940821885,
#  ('support', 'method'): 0.00015939256940821885,
#  ('implement', 'platform'): 0.00015939256940821885,
#  ('facilitate', 'access'): 0.00015939256940821885,
#  ('track', 'motion'): 0.00015939256940821885,
#  ('leverage', 'model'): 0.00015939256940821885,
#  ('learn', 'recognition'): 0.00015939256940821885,
#  ('screen', 'method'): 0.00015939256940821885,
#  ('determine', 'intent'): 0.00015939256940821885,
#  ('determine', 'segment'): 0.00015939256940821885,
#  ('generate', 'intelligence'): 0.00015939256940821885,
#  ('use', 'transformation'): 0.00015939256940821885,
#  ('retrieve', 'information'): 0.00015939256940821885,
#  ('analyze', 'threat'): 0.00015939256940821885,
#  ('improve', 'model'): 0.00015939256940821885,
#  ('select', 'datum'): 0.00015939256940821885,
#  ('support', 'communication'): 0.00015939256940821885,
#  ('suggest', 'action'): 0.00015939256940821885,
#  ('face', 'device'): 0.00015939256940821885,
#  ('generate', 'application'): 0.00015939256940821885,
#  ('learn', 'preference'): 0.00015939256940821885,
#  ('enhance', 'feature'): 0.00015939256940821885,
#  ('control', 'object'): 0.00015939256940821885,
#  ('make', 'recommendation'): 0.00015939256940821885,
#  ('reduce', 'power'): 0.00015939256940821885,
#  ('use', 'translation'): 0.00015939256940821885,
#  ('generate', 'alert'): 0.00015939256940821885,
#  ('use', 'statistic'): 0.00015939256940821885,
#  ('estimate', 'device'): 0.00015939256940821885,
#  ('use', 'apparatus'): 0.00015939256940821885,
#  ('perform', 'convolution'): 0.00015939256940821885,
#  ('attribute', 'method'): 0.00015939256940821885,
#  ('use', 'sound'): 0.00015939256940821885,
#  ('evaluate', 'response'): 0.00015939256940821885,
#  ('compute', 'method'): 0.00015939256940821885,
#  ('acquire', 'information'): 0.00015939256940821885,
#  ('generate', 'code'): 0.00015939256940821885,
#  ('generate', 'strategy'): 0.00015939256940821885,
#  ('compute', 'task'): 0.00015939256940821885,
#  ('use', 'state'): 0.00015939256940821885,
#  ('determine', 'behavior'): 0.00015939256940821885,
#  ('determine', 'language'): 0.00015939256940821885,
#  ('use', 'time'): 0.00015939256940821885,
#  ('identify', 'risk'): 0.00015939256940821885,
#  ('process', 'text'): 0.00015939256940821885,
#  ('identify', 'similarity'): 0.00015939256940821885,
#  ('transmit', 'channel'): 0.00015939256940821885,
#  ('fuse', 'knowledge'): 0.00015939256940821885,
#  ('resolve', 'ambiguity'): 0.00015939256940821885,
#  ('exploit', 'sparsity'): 0.00015939256940821885,
#  ('generate', 'report'): 0.00015939256940821885,
#  ('grade', 'method'): 0.00015939256940821885,
#  ('use', 'simulator'): 0.00015939256940821885,
#  ('select', 'parameter'): 0.00015939256940821885,
#  ('recommend', 'product'): 0.00015939256940821885,
#  ('integrate', 'technology'): 0.00015939256940821885,
#  ('learn', 'behavior'): 0.00015939256940821885,
#  ('enhance', 'awareness'): 0.0001449023358256535,
#  ('use', 'medium'): 0.0001449023358256535,
#  ('plan', 'trajectory'): 0.0001449023358256535,
#  ('detect', 'position'): 0.0001449023358256535,
#  ('monitor', 'process'): 0.0001449023358256535,
#  ('block', 'method'): 0.0001449023358256535,
#  ('mitigate', 'risk'): 0.0001449023358256535,
#  ('facilitate', 'processing'): 0.0001449023358256535,
#  ('route', 'system'): 0.0001449023358256535,
#  ('monitor', 'datum'): 0.0001449023358256535,
#  ('extract', 'graph'): 0.0001449023358256535,
#  ('combine', 'model'): 0.0001449023358256535,
#  ('set', 'device'): 0.0001449023358256535,
#  ('predict', 'information'): 0.0001449023358256535,
#  ('determine', 'strategy'): 0.0001449023358256535,
#  ('use', 'heuristic'): 0.0001449023358256535,
#  ('use', 'result'): 0.0001449023358256535,
#  ('minimize', 'cost'): 0.0001449023358256535,
#  ('test', 'application'): 0.0001449023358256535,
#  ('detect', 'account'): 0.0001449023358256535,
#  ('base', 'service'): 0.0001449023358256535,
#  ('optimize', 'method'): 0.0001449023358256535,
#  ('detect', 'line'): 0.0001449023358256535,
#  ('select', 'device'): 0.0001449023358256535,
#  ('detect', 'pattern'): 0.0001449023358256535,
#  ('generate', 'instruction'): 0.0001449023358256535,
#  ('assist', 'user'): 0.0001449023358256535,
#  ('manage', 'security'): 0.0001449023358256535,
#  ('identify', 'class'): 0.0001449023358256535,
#  ('improve', 'management'): 0.0001449023358256535,
#  ('assess', 'disease'): 0.0001449023358256535,
#  ('give', 'document'): 0.0001449023358256535,
#  ('identify', 'mode'): 0.0001449023358256535,
#  ('employ', 'network'): 0.0001449023358256535,
#  ('augment', 'reality'): 0.0001449023358256535,
#  ('populate', 'inventory'): 0.0001449023358256535,
#  ('learn', 'approach'): 0.0001449023358256535,
#  ('link', 'method'): 0.0001449023358256535,
#  ('report', 'method'): 0.0001449023358256535,
#  ('detect', 'area'): 0.0001449023358256535,
#  ('use', 'activity'): 0.0001449023358256535,
#  ('provide', 'program'): 0.0001449023358256535,
#  ('manage', 'event'): 0.0001449023358256535,
#  ('secure', 'network'): 0.0001449023358256535,
#  ('use', 'mechanism'): 0.0001449023358256535,
#  ('reduce', 'noise'): 0.0001449023358256535,
#  ('determine', 'category'): 0.0001449023358256535,
#  ('stack', 'method'): 0.0001449023358256535,
#  ('track', 'target'): 0.0001449023358256535,
#  ('read', 'terminal'): 0.0001449023358256535,
#  ('generate', 'rule'): 0.0001449023358256535,
#  ('track', 'system'): 0.0001449023358256535,
#  ('characterize', 'system'): 0.0001449023358256535,
#  ('encourage', 'compliance'): 0.0001449023358256535,
#  ('explain', 'model'): 0.0001449023358256535,
#  ('produce', 'model'): 0.0001449023358256535,
#  ('use', 'tag'): 0.0001449023358256535,
#  ('utilize', 'recognition'): 0.0001449023358256535,
#  ('enhance', 'content'): 0.0001449023358256535,
#  ('generate', 'avatar'): 0.0001449023358256535,
#  ('name', 'system'): 0.0001449023358256535,
#  ('base', 'processing'): 0.0001449023358256535,
#  ('use', 'curve'): 0.0001449023358256535,
#  ('have', 'sensor'): 0.0001449023358256535,
#  ('facilitate', 'conversation'): 0.0001449023358256535,
#  ...}

# %%
total_extracted_pairs
# Out:
# 69012

# %%
# Initialize dictionaries to store cumulative exposure values
weighted_sum_frequencies = {}
weighted_total_pairs = {}

# Step 4: Calculate the exposure score for each occupation
for idx, row in occupation_df.iterrows():
    occupation_name = row['Occupation Name']
    task_importances = [row['Task Importance']] * len(row['Matched Verb-Noun Pairs from AI']) if isinstance(row['Task Importance'], (int, float)) else [row['Task Importance']]

    print(f"\nProcessing occupation: {occupation_name}")

    # Initialize the weighted sum and total pairs for this occupation if not already done
    if occupation_name not in weighted_sum_frequencies:
        weighted_sum_frequencies[occupation_name] = 0
        weighted_total_pairs[occupation_name] = 0
    
    # Calculate the weighted sums for the current task based on matched verb-noun pairs, task importance, and AI frequencies
    current_weighted_sum = 0
    current_total_weighted_pairs = 0

    # Iterate over the matched verb-noun pairs for the task
    for pair in set(row['Matched Verb-Noun Pairs from AI']):  # Use set to avoid duplicates
        verb_noun = pair.split(' ')
        if len(verb_noun) != 2:
            print(f"Skipping invalid pair: {pair}")
            continue  # Skip invalid pairs if not exactly two parts

        verb, noun = verb_noun
        frequency = ai_frequencies.get((verb, noun), 0)  # Get the frequency from the dictionary (or 0 if not found)

        # Add the weighted frequency to the current weighted sum (task importance * frequency)
        current_weighted_sum += row['Task Importance'] * frequency
    
    # Add the weighted count of verb-noun pairs to the total weighted pairs for this task
    current_total_weighted_pairs += row['Task Importance'] * len(row['Matched Verb-Noun Pairs from AI'])

    # Update cumulative sums for the occupation
    weighted_sum_frequencies[occupation_name] += current_weighted_sum
    weighted_total_pairs[occupation_name] += current_total_weighted_pairs

# After processing all rows, calculate the exposure score for each occupation
exposure_scores = {
    occupation: weighted_sum_frequencies[occupation] / weighted_total_pairs[occupation] if weighted_total_pairs[occupation] > 0 else 0
    for occupation in weighted_sum_frequencies
}

# Convert exposure scores into a DataFrame for better visualization
exposure_scores_df = pd.DataFrame(list(exposure_scores.items()), columns=['Occupation Name', 'Exposure Score'])

# Save the exposure scores to a CSV file
#exposure_scores_df.to_csv('/Users/twylazhang/Desktop/Directed Research/code_output/6_calculate/occupation_exposure_scores.csv', index=False)
#exposure_scores_df.to_excel('/Users/twylazhang/Desktop/Directed Research/code_output/6_calculate/occupation_exposure_scores.xlsx', index=False)

# Print a preview of the result
print("\nExposure Scores Preview:")
print(exposure_scores_df.head())

# %%
occupation_df
# Out:
#                           Occupation Name      Task Verb-Noun  \
# 0                Accountants and Auditors      prepare report
# 1                Accountants and Auditors    recommend change
# 2                Accountants and Auditors       analyze datum
# 3                Accountants and Auditors      detect control
# 4                Accountants and Auditors        inspect book
# ...                                   ...                 ...
# 18039  Zoologists and Wildlife Biologists       conduct study
# 18040  Zoologists and Wildlife Biologists  coordinate program
# 18041  Zoologists and Wildlife Biologists    control outbreak
# 18042  Zoologists and Wildlife Biologists  prepare collection
# 18043  Zoologists and Wildlife Biologists    examine specimen
#
#        Task Importance                    Matched Verb-Noun Pairs from AI
# 0                 90.0                                  [identify report]
# 1                 89.0  [determine change, discover change, assist cha...
# 2                 88.0  [identify datum, visualize datum, evaluate dat...
# 3                 88.0  [detect distraction, detect substance, control...
# 4                 88.0  [reproduce book, book availability, distribute...
# ...                ...                                                ...
# 18039             67.0  [conduct research, study analysis, conduct exp...
# 18040             61.0  [construct program, program generator, convert...
# 18041             61.0  [control deployment, control transmission, con...
# 18042             52.0  [prioritize collection, prepare instruction, p...
# 18043             40.0              [analyze specimen, identify specimen]
#
# [18044 rows x 4 columns]

# %%
# Step 4: Calculate the exposure score for each occupation
for idx, row in occupation_df.iterrows():
    occupation_name = row['Occupation Name']
    task_importances = [row['Task Importance']] * len(row['Matched Verb-Noun Pairs from AI']) if isinstance(row['Task Importance'], (int, float)) else [row['Task Importance']]

    print(f"\nProcessing occupation: {occupation_name}")

    # Calculate the exposure score based on matched verb-noun pairs, task importance, and AI frequencies
    exposure_score = calculate_exposure_score(row['Task Verb-Noun'], task_importances, row['Matched Verb-Noun Pairs from AI'], ai_frequencies)
    exposure_scores[occupation_name] = exposure_score

# Convert exposure scores into a DataFrame for better visualization
exposure_scores_df = pd.DataFrame(list(exposure_scores.items()), columns=['Occupation Name', 'Exposure Score'])

# Save the exposure scores to a CSV file
#exposure_scores_df.to_csv('/Users/twylazhang/Desktop/Directed Research/code_output/6_calculate/occupation_exposure_scores.csv', index=False)
#exposure_scores_df.to_excel('/Users/twylazhang/Desktop/Directed Research/code_output/6_calculate/occupation_exposure_scores.xlsx', index=False)

# Print a preview of the result
print("\nExposure Scores Preview:")
print(exposure_scores_df.head())
